# %%
# %cd ~
# !git clone https://github.com/Grace9994/CoMoSVC.git
# Out:
# /home/aistudio
# Cloning into 'CoMoSVC'...
# remote: Enumerating objects: 240, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 240 (delta 1), reused 0 (delta 0), pack-reused 233
# Receiving objects: 100% (240/240), 100.31 KiB | 306.00 KiB/s, done.
# Resolving deltas: 100% (131/131), done.

# %%
# %cd ~
# !mkdir /root/autodl-tmp/external-libraries
# !pip install beautifulsoup4 -t /root/autodl-tmp/external-libraries
# %cd CoMoSVC
# !pip install -r requirements.txt -t /root/autodl-tmp/external-libraries

# %%
# %cd ~
# %cd /root/autodl-tmp/
# !mkdir /root/autodl-tmp/CoMoSVC/m4singer_hifigan
# !unzip m4singer_hifigan.zip -d /home/aistudio/CoMoSVC/
# !mkdir /root/autodl-tmp/CoMoSVC/Content
# !unzip m4singer_pe.zip -d /home/aistudio/CoMoSVC
# Out:
# /home/aistudio
# /home/aistudio/data/data263375
# Archive:  m4singer_hifigan.zip
#   inflating: /home/aistudio/CoMoSVC/m4singer_hifigan/config.yaml
#   inflating: /home/aistudio/CoMoSVC/m4singer_hifigan/model_ckpt_steps_1970000.ckpt
# mkdir: cannot create directory '/home/aistudio/CoMoSVC/Content': File exists
# Archive:  m4singer_pe.zip
# replace /home/aistudio/CoMoSVC/m4singer_pe/config.yaml? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
# %cd ~
# %cd /root/autodl-tmp/
# !mkdir /root/autodl-tmp/CoMoSVC/dataset_raw
# !mkdir /root/autodl-tmp/CoMoSVC/dataset
# !unzip m4singer.zip -d /root/autodl-tmp/CoMoSVC/dataset_raw

# %%
# %cd ~
# %cd /root/autodl-tmp/
# !unzip segments.zip -d /root/autodl-tmp/CoMoSVC/dataset_raw ###解压完后记得将文件夹名字改为Opencpop
# !unzip PopBuTFy.zip -d /root/autodl-tmp/CoMoSVC/dataset_raw
# Out:
# /home/aistudio
# /home/aistudio/data/data263592
# Archive:  segments.zip
# caution: filename not matched:  -p
# caution: filename not matched:  Mmwjxhn2017

# %%
# %cd ~
# %cd /root/autodl-tmp/
# !tar -zxvf OpenSinger.tar.gz -C /root/autodl-tmp/CoMoSVC/dataset_raw
# Out:
# /root
# /root/autodl-tmp
# tar (child): OpenSinger.tar.gz: Cannot open: No such file or directory
# tar (child): Error is not recoverable: exiting now
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now
# /root/miniconda3/lib/python3.10/site-packages/IPython/core/magics/osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# /root/miniconda3/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import sys 
sys.path.append('/root/autodl-fs/external-libraries')

# %% [markdown]
# 请点击[此处](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576)查看本环境基本用法.  <br>
# Please click [here ](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576) for more detailed instructions.

# %%
#重采样为24000Hz和单声道
#采样m4singer
import sys 
sys.path.append('/root/autodl-fs/external-libraries')
# %cd ~
# %cd autodl-tmp/CoMoSVC

# !python preprocessing1_resample_m4Singer.py -n 5
# Out:
# /root
# /root/autodl-tmp/CoMoSVC
# input_paths 0
# input_paths 0
# 0it [00:00, ?it/s]

# %%
#重采样为24000Hz和单声道
#采样OpenSinger
# %cd ~
# %cd autodl-tmp/CoMoSVC

# !python preprocessing1_resample_openSinger.py -n 4
# Out:
# /root
# /root/autodl-tmp/CoMoSVC
# input_paths 0
# input_paths 0
# 0it [00:00, ?it/s]

# %%
#去除PopBuTFy文件中歌曲名字的特殊符号
# %cd ~
# %cd autodl-tmp/CoMoSVC
# %cd dataset_raw/PopBuTFy/

# !for file in *\&*; do mv "$file" "${file//\&/}"; done
# Out:
# /root
# /root/autodl-tmp/CoMoSVC
# [Errno 2] No such file or directory: 'dataset_raw/PopBuTFy/'
# /root/autodl-tmp/CoMoSVC
# mv: cannot stat '*&*': No such file or directory

# %%
#将PopBuTFy中的音频格式转换为wav
# %cd ~
# %cd autodl-tmp/CoMoSVC

# !python any2Wav.py -in "/home/aistudio/CoMoSVC/dataset_raw/PopBuTFy/*/*.mp3" -out "/home/aistudio/CoMoSVC/dataset_raw/PopBuTFy_wav"
# Out:
# /root
# /root/autodl-tmp/CoMoSVC
# input_paths 0

# %%
#重采样为24000Hz和单声道
#采样PopBuTFy
# %cd ~
# %cd autodl-tmp/CoMoSVC

# !python preprocessing1_resample_PopBuTFy.py -n 5
# Out:
# /root
# /root/autodl-tmp/CoMoSVC
# input_paths 0
# input_paths 0
# 0it [00:00, ?it/s]

# %%
#重采样为24000Hz和单声道
#采样Opencpop
import sys 
sys.path.append('/root/autodl-fs/external-libraries')
# %cd ~
# %cd autodl-tmp/CoMoSVC

# !python preprocessing1_resample_Opencpop.py -n 5
# Out:
# /root
# /root/autodl-tmp/CoMoSVC
# input_paths 0
# input_paths 0
# 0it [00:00, ?it/s]

# %%
#重采样为24000Hz和单声道
#采样NSSH 
import sys 
sys.path.append('/root/autodl-fs/external-libraries')
# %cd ~
# %cd autodl-tmp/CoMoSVC

# !python preprocessing1_resample_NSSH.py -n 5
# Out:
# /root
# /root/autodl-tmp/CoMoSVC
# input_paths 0
# input_paths 0
# 0it [00:00, ?it/s]

# %%
#将NUS数据集的语音切片
# %cd ~
# %cd autodl-tmp/CoMoSVC

# !python preparation_slice.py
# Out:
# /root
# /root/autodl-tmp/CoMoSVC
# /root/autodl-tmp/external-libraries/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# input_paths 0

# %%
#重采样为24000Hz和单声道
#采样NUS
import sys 
sys.path.append('/root/autodl-fs/external-libraries')
# %cd ~
# %cd autodl-tmp/CoMoSVC

# !python preprocessing1_resample_NUS.py -n 5
# Out:
# /root
# /root/autodl-tmp/CoMoSVC
# input_paths 0
# input_paths 0
# 0it [00:00, ?it/s]

# %%
import sys 
sys.path.append('/home/aistudio/external-libraries')

import librosa
import os,tqdm
import multiprocessing as mp
import soundfile as sf
from glob import glob
import argparse

input_paths = glob('CoMoSVC/dataset_raw/OpenSinger/ManRaw/0_斑马，斑马/*.wav')
input_paths = list(set(input_paths))
print("input_paths",len(input_paths))
for input_path in input_paths:
    singer="OpenSinger-" + input_path.split('/')[-3].split('R')[-2] + input_path.split('/')[-2].split('_')[-2]
    songname=input_path.split('/')[-2].split('_')[-1]
    wavnum=input_path.split('/')[-1].split('_')[-1]
    output_path='dataset/'+singer+'/'+songname
    output_path=output_path + wavnum 
    print(singer+'  '+ songname+'  '+wavnum+'   '+output_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 4
#       1 import sys
#       2 sys.path.append('/home/aistudio/external-libraries')
# ----> 4 import librosa
#       5 import os,tqdm
#       6 import multiprocessing as mp
#
# ModuleNotFoundError: No module named 'librosa'

# %%
import sys 
sys.path.append('/root/autodl-fs/external-libraries')

import librosa
import os,tqdm
import multiprocessing as mp
import soundfile as sf
from glob import glob
import argparse

totD = 0
count = 0
input_paths = glob('CoMoSVC/dataset_raw/PopBuTFy/*/*.mp3') 
tot=len(input_paths)
input_paths = list(set(input_paths))
for input_path in input_paths:
    y, sr = librosa.load(input_path)
    totD =totD + librosa.get_duration(y=y, sr=sr)
    count=count + 1
    print(count,'/',tot)
print(totD)

# %%
#数据集时长统计
# %cd ~
# %cd CoMoSVC
import sys 
sys.path.append('/home/aistudio/external-libraries')
sys.path.append('/home/aistudio/CoMoSVC')
import argparse
import os
import re
import wave
from random import shuffle

from loguru import logger
from tqdm import tqdm

import utils

train = []
val = []
idx = 0
spk_dict = {}
spk_id = 0

source_dir="dataset"
prefix = "PopBuTFy"
data_path="./dataset/" + prefix + "*" + "/*.wav"
print(data_path)
folders_with_prefix = [folder for folder in os.listdir(source_dir)
                       if folder.startswith(prefix) and os.path.isdir(os.path.join(source_dir, folder))]
#print(folders_with_prefix)
for speaker in tqdm(folders_with_prefix):
        spk_dict[speaker] = spk_id
        spk_id += 1
        #print(speaker)
        #for file_name in os.listdir(os.path.join(source_dir, speaker)):
            #print(file_name)
# Out:
# /home/aistudio
# /home/aistudio/CoMoSVC
# ./dataset/PopBuTFy*/*.wav
# 100%|██████████| 24/24 [00:00<00:00, 185725.64it/s]

# %%
#分割训练和验证数据集，并生成配置文件
import sys 
sys.path.append('/root/autodl-fs/external-libraries')
# %cd ~
# %cd autodl-tmp/CoMoSVC
# !python preprocessing2_flist.py #--dataset_prefix "PopBuTFy"
#只用PopBuTFy训练
# Out:
# /root
# /root/autodl-tmp/CoMoSVC
#  91%|█████████████████████████████████████▏   | 116/128 [00:06<00:00, 26.87it/s]2024-03-31 16:15:07.390 | INFO     | __main__:<module>:61 - Skip too short audio: ./dataset/NUS-MPOL/NUS-read208.wav
# 2024-03-31 16:15:07.415 | INFO     | __main__:<module>:61 - Skip too short audio: ./dataset/NUS-MCUR/NUS-read1716.wav
# 2024-03-31 16:15:07.468 | INFO     | __main__:<module>:61 - Skip too short audio: ./dataset/NUS-VKOW/NUS-sing0520.wav
# 2024-03-31 16:15:07.471 | INFO     | __main__:<module>:61 - Skip too short audio: ./dataset/NUS-VKOW/NUS-sing1923.wav
#  96%|███████████████████████████████████████▍ | 123/128 [00:06<00:00, 37.79it/s]2024-03-31 16:15:07.509 | INFO     | __main__:<module>:61 - Skip too short audio: ./dataset/NUS-ZHIY/NUS-read026.wav
# 2024-03-31 16:15:07.549 | INFO     | __main__:<module>:61 - Skip too short audio: ./dataset/NUS-NJAT/NUS-read158.wav
# 100%|█████████████████████████████████████████| 128/128 [00:07<00:00, 18.18it/s]
# ...

# %%
#清空数据集中已经有的特征
import sys 
sys.path.append('/root/autodl-tmp/external-libraries')
# !find autodl-tmp/CoMoSVC/dataset/ -type f -name "*.pt" -exec rm {} +
# !find autodl-tmp/CoMoSVC/dataset/ -type f -name "*.npy" -exec rm {} +
#!rm -rf m4Singer*

# %%
#生成特征
#7229条特征 约等 48G
#提前预估硬盘空间够不够
# %cd ~
# %cd autodl-tmp/CoMoSVC
import sys 
sys.path.append('/root/autodl-fs/external-libraries')
    
# !python preprocessing3_feature.py -n 5 --dataset_prefix "NUS"
# Out:
# /root
# /root/autodl-tmp/CoMoSVC
# 2024-03-28 21:29:51.727 | INFO     | __main__:<module>:137 - Using device: cuda
# Loading Mel Extractor... m4-gan
#   0%|                                                     | 0/5 [00:00<?, ?it/s]2024-03-28 21:29:54.486 | INFO     | __mp_main__:process_batch:100 - Loading speech encoder for content...
# 2024-03-28 21:29:54.486 | INFO     | __mp_main__:process_batch:100 - Loading speech encoder for content...
# 2024-03-28 21:29:54.553 | INFO     | __mp_main__:process_batch:106 - Rank 3 uses device cuda:0
# 2024-03-28 21:29:54.553 | INFO     | __mp_main__:process_batch:106 - Rank 4 uses device cuda:0
# 2024-03-28 21:29:54.607 | INFO     | __mp_main__:process_batch:100 - Loading speech encoder for content...
# 2024-03-28 21:29:54.627 | INFO     | __mp_main__:process_batch:100 - Loading speech encoder for content...
# 2024-03-28 21:29:54.644 | INFO     | __mp_main__:process_batch:100 - Loading speech encoder for content...
# ...

# %%
#训练 teacher model
# %cd ~
# %cd autodl-tmp/CoMoSVC
import sys 
sys.path.append('/root/autodl-fs/external-libraries')

# !python train.py
# Out:
# /root
# /root/autodl-tmp/CoMoSVC
# /root/miniconda3/lib/python3.10/site-packages/IPython/core/magics/osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# /root/miniconda3/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# 2024-04-05 12:12:42.799 | INFO     | __main__:<module>:60 -  > config:configs/diffusion.yaml
#  [*] restoring model from logs/teacher/model_370000.pt
# 2024-04-05 12:12:43.991 | INFO     | __main__:<module>:109 -  > The Teacher Model is training now.
# cuda
# Load all the data filelists: filelists/train.txt
# 100%|████████████████████████████████████| 71115/71115 [04:50<00:00, 244.87it/s]
# Load all the data filelists: filelists/val.txt
# 100%|████████████████████████████████████████| 185/185 [00:00<00:00, 210.88it/s]
# ...

# %%
#训练 consistency model
# %cd ~
# %cd autodl-tmp/CoMoSVC

# !python train.py -t -p ./logs/teacher/model_360000.pt
# Out:
# /root
# /root/autodl-tmp/CoMoSVC
# /root/miniconda3/lib/python3.10/site-packages/IPython/core/magics/osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# /root/miniconda3/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# 2024-04-07 14:35:22.333 | INFO     | __main__:<module>:60 -  > config:configs/diffusion.yaml
#  [*] restoring model from logs/como/model_430000.pt
# 2024-04-07 14:35:24.027 | INFO     | __main__:<module>:111 -  > The Student Model CoMoSVC is training now.
# cuda
# Load all the data filelists: filelists/train.txt
# 100%|████████████████████████████████████| 71115/71115 [03:15<00:00, 364.56it/s]
# Load all the data filelists: filelists/val.txt
# 100%|████████████████████████████████████████| 185/185 [00:00<00:00, 206.64it/s]
# ...

# %%
#采用教师模型的推理
# %cd ~
# %cd autodl-tmp/CoMoSVC
#-ts 教师模型推理时的迭代步数
#-tm 教师模型路径
#-tc 教师模型配置文件
#-n source音频路径
#-k pitch shift，可以是正负semitone值
#-s 目标歌手
# !python inference_main.py -ts 20000 -tm "logs/teacher/model_360000.pt" -tc "logs/teacher/config.yaml" -n "暖暖27.wav" -k 0 -s "OpenSinger-Woman35"

# %%
#采用CoMoSVC进行推理
# %cd ~
# %cd autodl-tmp/CoMoSVC
#-ts 学生模型推理时的迭代步数
#-cm CoMoSVC模型路径
#-cc CoMoSVC模型配置文件
#-t 加上该参数并保留后续为空代表不是教师模型
# !python inference_main.py -ts 25000 -cm "logs/como/model_224000.pt" -cc "logs/como/config.yaml" -n "大鱼15.wav" -k 0 -s "OpenSinger-Man7" -t
